# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import Birch

# Load dataset
dataset = pd.read_csv("Mall_Customers.csv")

# Select features (Annual Income and Spending Score)
X = dataset.iloc[:, [3, 4]].values

# Apply BIRCH
birch = Birch(n_clusters=5)   # you can set n_clusters or leave it None
y_birch = birch.fit_predict(X)

# Add cluster labels to the dataset
dataset["Cluster"] = y_birch

# Visualize clusters with lmplot
facet = sns.lmplot(
    data=dataset,
    x="Annual Income (k$)",
    y="Spending Score (1-100)",
    hue="Cluster",
    fit_reg=False,
    legend_out=True,
    palette="Set1"
)

plt.title("BIRCH Clustering")
plt.show()
# Out:
# C:\Anaconda3\Lib\site-packages\seaborn\regression.py:598: UserWarning: legend_out is deprecated from the `lmplot` function signature. Please update your code to pass it using `facet_kws`.
#   warnings.warn(msg, UserWarning)
